# %%
# %% CELL 1: Setup and Imports
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from sklearn.model_selection import train_test_split
import time
import os

# Check GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")
if device.type == 'cuda':
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# %% CELL 2: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Create output directory
OUTPUT_DIR = '/content/drive/MyDrive/word_problem_results/B3'
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Results will be saved to: {OUTPUT_DIR}")

# %% CELL 3: Set Data Directory
DATA_DIR = '/content/B3'

# %% CELL 4: Load Datasets
df_synthetic = pd.read_csv(os.path.join(DATA_DIR, 'b3_synthetic_100k.csv'))
df_augmented = pd.read_csv(os.path.join(DATA_DIR, 'b3_augmented_100k.csv'))
df_hard = pd.read_csv(os.path.join(DATA_DIR, 'b3_hard_100k.csv'))

datasets = {
    'synthetic': df_synthetic,
    'augmented': df_augmented,
    'hard': df_hard
}

for name, df in datasets.items():
    print(f"{name}: {len(df)} rows, {df['label'].sum()} identity, {len(df) - df['label'].sum()} non-identity")

# %% CELL 5: Quick Data Check
print(f"\nSynthetic: {len(df_synthetic)} rows")
print(f"Augmented: {len(df_augmented)} rows")
print(f"Hard: {len(df_hard)} rows")
print(df_synthetic.head())
# Out:
# Device: cuda
# GPU: NVIDIA A100-SXM4-40GB
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Results will be saved to: /content/drive/MyDrive/word_problem_results/B3
# synthetic: 100000 rows, 50000 identity, 50000 non-identity
# augmented: 100000 rows, 50000 identity, 50000 non-identity
# hard: 100000 rows, 50000 identity, 50000 non-identity
#
# Synthetic: 100000 rows
# Augmented: 100000 rows
# Hard: 100000 rows
#                                                 word  label  length  \
# 0  S2 S2 S2 s1 s2 S2 S1 s2 s1 s2 S1 s2 s2 s2 S2 S...      0      27
# 1  s1 s1 S2 s2 s1 s2 S1 s2 s1 s1 S1 s1 s2 s1 s1 s...      1      42
# 2  s1 S2 s1 S1 s2 s2 s1 S1 S2 s1 S2 s1 S2 s2 s1 s...      0      30
# 3  s2 S1 s1 s2 S2 S1 s2 S1 s1 s1 s2 S2 S2 s1 S2 s...      0      49
# 4  s1 S2 s1 S2 s2 S1 s2 s2 S1 S1 S2 s2 s2 s1 s1 s...      1      38
#
#               source
# 0  b3_synthetic_100k
# 1  b3_synthetic_100k
# 2  b3_synthetic_100k
# 3  b3_synthetic_100k
# 4  b3_synthetic_100k

# %%
# %% CELL 6: Tokenizer
# B3 alphabet: s1, S1 (inverse), s2, S2 (inverse) - space-separated
sample_word = df_synthetic['word'].iloc[0]
print(f"Sample word: '{sample_word}'")

if ' ' in sample_word:
    # Space-separated tokens (s1 S1 s2 S2)
    VOCAB = {'<PAD>': 0, 's1': 1, 'S1': 2, 's2': 3, 'S2': 4}
    def encode(word):
        return [VOCAB.get(t, 0) for t in word.split()]
else:
    # Character-based fallback
    VOCAB = {'<PAD>': 0}
    all_chars = set()
    for word in df_synthetic['word'].head(1000):
        all_chars.update(word)
    for i, c in enumerate(sorted(all_chars)):
        VOCAB[c] = i + 1
    def encode(word):
        return [VOCAB.get(c, 0) for c in word]

VOCAB_SIZE = len(VOCAB)
print(f"Vocab ({VOCAB_SIZE} tokens): {VOCAB}")
print(f"encode('{sample_word}') = {encode(sample_word)}")

# %% CELL 7: Dataset Class
class WordProblemDataset(Dataset):
    def __init__(self, words, labels):
        self.words = words
        self.labels = labels

    def __len__(self):
        return len(self.words)

    def __getitem__(self, idx):
        encoded = encode(self.words[idx])
        return encoded, self.labels[idx], len(encoded)

def collate_fn(batch):
    words, labels, lengths = zip(*batch)
    max_len = max(lengths)

    padded = []
    for w in words:
        padded.append(w + [0] * (max_len - len(w)))

    sorted_indices = sorted(range(len(lengths)), key=lambda i: lengths[i], reverse=True)

    padded_sorted = [padded[i] for i in sorted_indices]
    labels_sorted = [labels[i] for i in sorted_indices]
    lengths_sorted = [lengths[i] for i in sorted_indices]

    return (
        torch.tensor(padded_sorted),
        torch.tensor(labels_sorted, dtype=torch.float),
        torch.tensor(lengths_sorted)
    )

# %% CELL 8: LSTM Model
class LSTMClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim=64, hidden_dim=128,
                 num_layers=2, dropout=0.3, bidirectional=True):
        super().__init__()
        self.bidirectional = bidirectional

        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)

        self.lstm = nn.LSTM(
            input_size=embed_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0,
            bidirectional=bidirectional
        )

        lstm_output_dim = hidden_dim * 2 if bidirectional else hidden_dim

        self.classifier = nn.Sequential(
            nn.Linear(lstm_output_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, 1)
        )

    def forward(self, input_ids, lengths):
        embedded = self.embedding(input_ids)
        packed = pack_padded_sequence(embedded, lengths.cpu(), batch_first=True, enforce_sorted=True)
        _, (hidden, _) = self.lstm(packed)

        if self.bidirectional:
            hidden = torch.cat([hidden[-2], hidden[-1]], dim=1)
        else:
            hidden = hidden[-1]

        return self.classifier(hidden).squeeze(-1)

# %% CELL 9: Transformer Model
class TransformerClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim=64, num_heads=4,
                 num_layers=2, dropout=0.3, max_len=200):
        super().__init__()

        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.pos_encoding = nn.Embedding(max_len, embed_dim)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=embed_dim,
            nhead=num_heads,
            dim_feedforward=embed_dim * 4,
            dropout=dropout,
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        self.classifier = nn.Sequential(
            nn.Linear(embed_dim, embed_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(embed_dim, 1)
        )

    def forward(self, input_ids, lengths):
        batch_size, seq_len = input_ids.shape

        positions = torch.arange(seq_len, device=input_ids.device).unsqueeze(0).expand(batch_size, -1)
        embedded = self.embedding(input_ids) + self.pos_encoding(positions)

        mask = (input_ids == 0)

        output = self.transformer(embedded, src_key_padding_mask=mask)

        mask_expanded = (~mask).unsqueeze(-1).float()
        pooled = (output * mask_expanded).sum(dim=1) / mask_expanded.sum(dim=1).clamp(min=1)

        return self.classifier(pooled).squeeze(-1)

print("Models defined: LSTMClassifier, TransformerClassifier")

# %% CELL 10: Training Function
def train_model(model, train_loader, val_loader, epochs=30, patience=5, lr=0.001):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()

    best_val_acc = 0
    best_model_state = None
    patience_counter = 0
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

    for epoch in range(epochs):
        model.train()
        train_loss, train_correct, train_total = 0, 0, 0

        for input_ids, labels, lengths in train_loader:
            input_ids, labels, lengths = input_ids.to(device), labels.to(device), lengths.to(device)

            optimizer.zero_grad()
            outputs = model(input_ids, lengths)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            preds = (torch.sigmoid(outputs) > 0.5).float()
            train_correct += (preds == labels).sum().item()
            train_total += labels.size(0)

        train_acc = train_correct / train_total

        model.eval()
        val_loss, val_correct, val_total = 0, 0, 0

        with torch.no_grad():
            for input_ids, labels, lengths in val_loader:
                input_ids, labels, lengths = input_ids.to(device), labels.to(device), lengths.to(device)
                outputs = model(input_ids, lengths)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                preds = (torch.sigmoid(outputs) > 0.5).float()
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        val_acc = val_correct / val_total

        history['train_loss'].append(train_loss / len(train_loader))
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss / len(val_loader))
        history['val_acc'].append(val_acc)

        print(f"Epoch {epoch+1}/{epochs} | Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model_state = model.state_dict().copy()
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

    if best_model_state:
        model.load_state_dict(best_model_state)

    return history, best_val_acc

# %% CELL 11: Evaluation Function
def evaluate_model(model, test_loader):
    model.eval()
    correct, total = 0, 0
    all_preds, all_labels = [], []

    with torch.no_grad():
        for input_ids, labels, lengths in test_loader:
            input_ids, labels, lengths = input_ids.to(device), labels.to(device), lengths.to(device)
            outputs = model(input_ids, lengths)
            preds = (torch.sigmoid(outputs) > 0.5).float()

            correct += (preds == labels).sum().item()
            total += labels.size(0)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = correct / total
    return accuracy, all_preds, all_labels

# %% CELL 12: Length Generalization Test
def test_length_generalization(model, df, train_max_len=50):
    long_df = df[df['length'] > train_max_len].copy()
    if len(long_df) == 0:
        return None, 0

    dataset = WordProblemDataset(long_df['word'].tolist(), long_df['label'].tolist())
    loader = DataLoader(dataset, batch_size=64, collate_fn=collate_fn)

    acc, _, _ = evaluate_model(model, loader)
    return acc, len(long_df)

# %% CELL 13: Run Single Experiment
def run_experiment(df, model_type, seed, dataset_name):
    print(f"\n{'='*60}")
    print(f"Model: {model_type} | Dataset: {dataset_name} | Seed: {seed}")
    print(f"{'='*60}")

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)

    train_df, temp_df = train_test_split(df, test_size=0.3, random_state=seed)
    val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=seed)

    train_dataset = WordProblemDataset(train_df['word'].tolist(), train_df['label'].tolist())
    val_dataset = WordProblemDataset(val_df['word'].tolist(), val_df['label'].tolist())
    test_dataset = WordProblemDataset(test_df['word'].tolist(), test_df['label'].tolist())

    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, collate_fn=collate_fn)
    val_loader = DataLoader(val_dataset, batch_size=64, collate_fn=collate_fn)
    test_loader = DataLoader(test_dataset, batch_size=64, collate_fn=collate_fn)

    print(f"Train: {len(train_dataset)} | Val: {len(val_dataset)} | Test: {len(test_dataset)}")

    if model_type == 'LSTM':
        model = LSTMClassifier(VOCAB_SIZE).to(device)
    else:
        model = TransformerClassifier(VOCAB_SIZE).to(device)

    params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"Parameters: {params:,}")

    start_time = time.time()
    history, best_val_acc = train_model(model, train_loader, val_loader)
    train_time = time.time() - start_time

    test_acc, _, _ = evaluate_model(model, test_loader)

    len_gen_acc, len_gen_count = test_length_generalization(model, df)

    print(f"\nResults:")
    print(f"  Test Accuracy: {test_acc:.4f}")
    print(f"  Training Time: {train_time:.1f}s")
    if len_gen_acc:
        print(f"  Length Gen Accuracy: {len_gen_acc:.4f} (n={len_gen_count})")

    return {
        'model': model_type,
        'dataset': dataset_name,
        'seed': seed,
        'test_acc': test_acc,
        'val_acc': best_val_acc,
        'train_time': train_time,
        'len_gen_acc': len_gen_acc,
        'len_gen_count': len_gen_count,
        'epochs': len(history['train_acc'])
    }
# Out:
# Sample word: 'S2 S2 S2 s1 s2 S2 S1 s2 s1 s2 S1 s2 s2 s2 S2 S1 s2 S2 S1 s1 s2 S2 s1 S1 S2 s2 s2'
# Vocab (5 tokens): {'<PAD>': 0, 's1': 1, 'S1': 2, 's2': 3, 'S2': 4}
# encode('S2 S2 S2 s1 s2 S2 S1 s2 s1 s2 S1 s2 s2 s2 S2 S1 s2 S2 S1 s1 s2 S2 s1 S1 S2 s2 s2') = [4, 4, 4, 1, 3, 4, 2, 3, 1, 3, 2, 3, 3, 3, 4, 2, 3, 4, 2, 1, 3, 4, 1, 2, 4, 3, 3]
# Models defined: LSTMClassifier, TransformerClassifier

# %%
# %% CELL 14: Run All Experiments
SEEDS = [42, 123, 456]
MODEL_TYPES = ['LSTM', 'Transformer']
DATASET_NAMES = ['synthetic', 'augmented', 'hard']

all_results = []

for dataset_name in DATASET_NAMES:
    df = datasets[dataset_name]
    for model_type in MODEL_TYPES:
        for seed in SEEDS:
            result = run_experiment(df, model_type, seed, dataset_name)
            all_results.append(result)

            results_df = pd.DataFrame(all_results)
            results_df.to_csv(f'{OUTPUT_DIR}/b3_results_partial.csv', index=False)

print("\n" + "="*60)
print("ALL EXPERIMENTS COMPLETE")
print("="*60)
# Out:
# ============================================================
# Model: LSTM | Dataset: synthetic | Seed: 42
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.9366 | Val Acc: 0.9831
# Epoch 2/30 | Train Acc: 0.9833 | Val Acc: 0.9890
# Epoch 3/30 | Train Acc: 0.9889 | Val Acc: 0.9914
# Epoch 4/30 | Train Acc: 0.9933 | Val Acc: 0.9954
# Epoch 5/30 | Train Acc: 0.9958 | Val Acc: 0.9958
# Epoch 6/30 | Train Acc: 0.9966 | Val Acc: 0.9975
# Epoch 7/30 | Train Acc: 0.9976 | Val Acc: 0.9963
# Epoch 8/30 | Train Acc: 0.9983 | Val Acc: 0.9970
# Epoch 9/30 | Train Acc: 0.9984 | Val Acc: 0.9974
# Epoch 10/30 | Train Acc: 0.9987 | Val Acc: 0.9984
# Epoch 11/30 | Train Acc: 0.9990 | Val Acc: 0.9980
# Epoch 12/30 | Train Acc: 0.9988 | Val Acc: 0.9983
# Epoch 13/30 | Train Acc: 0.9989 | Val Acc: 0.9983
# Epoch 14/30 | Train Acc: 0.9994 | Val Acc: 0.9981
# Epoch 15/30 | Train Acc: 0.9993 | Val Acc: 0.9984
# Early stopping at epoch 15
#
# Results:
#   Test Accuracy: 0.9989
#   Training Time: 271.7s
#
# ============================================================
# Model: LSTM | Dataset: synthetic | Seed: 123
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.9349 | Val Acc: 0.9726
# Epoch 2/30 | Train Acc: 0.9850 | Val Acc: 0.9899
# Epoch 3/30 | Train Acc: 0.9903 | Val Acc: 0.9917
# Epoch 4/30 | Train Acc: 0.9923 | Val Acc: 0.9940
# Epoch 5/30 | Train Acc: 0.9956 | Val Acc: 0.9943
# Epoch 6/30 | Train Acc: 0.9964 | Val Acc: 0.9963
# Epoch 7/30 | Train Acc: 0.9972 | Val Acc: 0.9977
# Epoch 8/30 | Train Acc: 0.9982 | Val Acc: 0.9982
# Epoch 9/30 | Train Acc: 0.9980 | Val Acc: 0.9988
# Epoch 10/30 | Train Acc: 0.9984 | Val Acc: 0.9975
# Epoch 11/30 | Train Acc: 0.9980 | Val Acc: 0.9992
# Epoch 12/30 | Train Acc: 0.9993 | Val Acc: 0.9990
# Epoch 13/30 | Train Acc: 0.9991 | Val Acc: 0.9991
# Epoch 14/30 | Train Acc: 0.9991 | Val Acc: 0.9988
# Epoch 15/30 | Train Acc: 0.9991 | Val Acc: 0.9992
# Epoch 16/30 | Train Acc: 0.9992 | Val Acc: 0.9990
# Early stopping at epoch 16
#
# Results:
#   Test Accuracy: 0.9987
#   Training Time: 289.9s
#
# ============================================================
# Model: LSTM | Dataset: synthetic | Seed: 456
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.9518 | Val Acc: 0.9873
# Epoch 2/30 | Train Acc: 0.9930 | Val Acc: 0.9946
# Epoch 3/30 | Train Acc: 0.9953 | Val Acc: 0.9959
# Epoch 4/30 | Train Acc: 0.9964 | Val Acc: 0.9957
# Epoch 5/30 | Train Acc: 0.9975 | Val Acc: 0.9982
# Epoch 6/30 | Train Acc: 0.9977 | Val Acc: 0.9984
# Epoch 7/30 | Train Acc: 0.9984 | Val Acc: 0.9987
# Epoch 8/30 | Train Acc: 0.9983 | Val Acc: 0.9969
# Epoch 9/30 | Train Acc: 0.9988 | Val Acc: 0.9971
# Epoch 10/30 | Train Acc: 0.9986 | Val Acc: 0.9981
# Epoch 11/30 | Train Acc: 0.9988 | Val Acc: 0.9984
# Epoch 12/30 | Train Acc: 0.9991 | Val Acc: 0.9983
# Early stopping at epoch 12
#
# Results:
#   Test Accuracy: 0.9987
#   Training Time: 216.6s
#
# ============================================================
# Model: Transformer | Dataset: synthetic | Seed: 42
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.9096 | Val Acc: 0.9870
# Epoch 2/30 | Train Acc: 0.9745 | Val Acc: 0.9875
# Epoch 3/30 | Train Acc: 0.9803 | Val Acc: 0.9881
# Epoch 4/30 | Train Acc: 0.9810 | Val Acc: 0.9861
# Epoch 5/30 | Train Acc: 0.9831 | Val Acc: 0.9799
# Epoch 6/30 | Train Acc: 0.9835 | Val Acc: 0.9895
# Epoch 7/30 | Train Acc: 0.9838 | Val Acc: 0.9906
# Epoch 8/30 | Train Acc: 0.9836 | Val Acc: 0.9927
# Epoch 9/30 | Train Acc: 0.9849 | Val Acc: 0.9899
# Epoch 10/30 | Train Acc: 0.9853 | Val Acc: 0.9905
# Epoch 11/30 | Train Acc: 0.9866 | Val Acc: 0.9921
# Epoch 12/30 | Train Acc: 0.9862 | Val Acc: 0.9918
# Epoch 13/30 | Train Acc: 0.9865 | Val Acc: 0.9873
# Early stopping at epoch 13
#
# Results:
#   Test Accuracy: 0.9865
#   Training Time: 137.4s
#
# ============================================================
# Model: Transformer | Dataset: synthetic | Seed: 123
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.9227 | Val Acc: 0.9709
# Epoch 2/30 | Train Acc: 0.9745 | Val Acc: 0.9895
# Epoch 3/30 | Train Acc: 0.9795 | Val Acc: 0.9915
# Epoch 4/30 | Train Acc: 0.9814 | Val Acc: 0.9883
# Epoch 5/30 | Train Acc: 0.9804 | Val Acc: 0.9849
# Epoch 6/30 | Train Acc: 0.9831 | Val Acc: 0.9897
# Epoch 7/30 | Train Acc: 0.9841 | Val Acc: 0.9883
# Epoch 8/30 | Train Acc: 0.9835 | Val Acc: 0.9901
# Early stopping at epoch 8
#
# Results:
#   Test Accuracy: 0.9905
#   Training Time: 84.6s
#
# ============================================================
# Model: Transformer | Dataset: synthetic | Seed: 456
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.8854 | Val Acc: 0.9797
# Epoch 2/30 | Train Acc: 0.9746 | Val Acc: 0.9809
# Epoch 3/30 | Train Acc: 0.9807 | Val Acc: 0.9859
# Epoch 4/30 | Train Acc: 0.9815 | Val Acc: 0.9877
# Epoch 5/30 | Train Acc: 0.9817 | Val Acc: 0.9818
# Epoch 6/30 | Train Acc: 0.9845 | Val Acc: 0.9872
# Epoch 7/30 | Train Acc: 0.9851 | Val Acc: 0.9893
# Epoch 8/30 | Train Acc: 0.9854 | Val Acc: 0.9843
# Epoch 9/30 | Train Acc: 0.9851 | Val Acc: 0.9895
# Epoch 10/30 | Train Acc: 0.9855 | Val Acc: 0.9858
# Epoch 11/30 | Train Acc: 0.9859 | Val Acc: 0.9913
# Epoch 12/30 | Train Acc: 0.9870 | Val Acc: 0.9842
# Epoch 13/30 | Train Acc: 0.9865 | Val Acc: 0.9913
# Epoch 14/30 | Train Acc: 0.9865 | Val Acc: 0.9909
# Epoch 15/30 | Train Acc: 0.9871 | Val Acc: 0.9891
# Epoch 16/30 | Train Acc: 0.9874 | Val Acc: 0.9908
# Early stopping at epoch 16
#
# Results:
#   Test Accuracy: 0.9910
#   Training Time: 168.7s
#
# ============================================================
# Model: LSTM | Dataset: augmented | Seed: 42
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.9428 | Val Acc: 0.9889
# Epoch 2/30 | Train Acc: 0.9875 | Val Acc: 0.9950
# Epoch 3/30 | Train Acc: 0.9920 | Val Acc: 0.9920
# Epoch 4/30 | Train Acc: 0.9924 | Val Acc: 0.9960
# Epoch 5/30 | Train Acc: 0.9947 | Val Acc: 0.9957
# Epoch 6/30 | Train Acc: 0.9955 | Val Acc: 0.9975
# Epoch 7/30 | Train Acc: 0.9965 | Val Acc: 0.9971
# Epoch 8/30 | Train Acc: 0.9975 | Val Acc: 0.9983
# Epoch 9/30 | Train Acc: 0.9980 | Val Acc: 0.9988
# Epoch 10/30 | Train Acc: 0.9980 | Val Acc: 0.9987
# Epoch 11/30 | Train Acc: 0.9987 | Val Acc: 0.9987
# Epoch 12/30 | Train Acc: 0.9987 | Val Acc: 0.9989
# Epoch 13/30 | Train Acc: 0.9991 | Val Acc: 0.9990
# Epoch 14/30 | Train Acc: 0.9989 | Val Acc: 0.9986
# Epoch 15/30 | Train Acc: 0.9990 | Val Acc: 0.9989
# Epoch 16/30 | Train Acc: 0.9992 | Val Acc: 0.9991
# Epoch 17/30 | Train Acc: 0.9992 | Val Acc: 0.9989
# Epoch 18/30 | Train Acc: 0.9997 | Val Acc: 0.9986
# Epoch 19/30 | Train Acc: 0.9992 | Val Acc: 0.9991
# Epoch 20/30 | Train Acc: 0.9994 | Val Acc: 0.9990
# Epoch 21/30 | Train Acc: 0.9994 | Val Acc: 0.9987
# Early stopping at epoch 21
#
# Results:
#   Test Accuracy: 0.9988
#   Training Time: 375.1s
#
# ============================================================
# Model: LSTM | Dataset: augmented | Seed: 123
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.9438 | Val Acc: 0.9915
# Epoch 2/30 | Train Acc: 0.9883 | Val Acc: 0.9909
# Epoch 3/30 | Train Acc: 0.9926 | Val Acc: 0.9915
# Epoch 4/30 | Train Acc: 0.9944 | Val Acc: 0.9951
# Epoch 5/30 | Train Acc: 0.9953 | Val Acc: 0.9945
# Epoch 6/30 | Train Acc: 0.9970 | Val Acc: 0.9975
# Epoch 7/30 | Train Acc: 0.9970 | Val Acc: 0.9976
# Epoch 8/30 | Train Acc: 0.9985 | Val Acc: 0.9969
# Epoch 9/30 | Train Acc: 0.9984 | Val Acc: 0.9980
# Epoch 10/30 | Train Acc: 0.9984 | Val Acc: 0.9981
# Epoch 11/30 | Train Acc: 0.9989 | Val Acc: 0.9983
# Epoch 12/30 | Train Acc: 0.9988 | Val Acc: 0.9984
# Epoch 13/30 | Train Acc: 0.9989 | Val Acc: 0.9983
# Epoch 14/30 | Train Acc: 0.9993 | Val Acc: 0.9983
# Epoch 15/30 | Train Acc: 0.9990 | Val Acc: 0.9986
# Epoch 16/30 | Train Acc: 0.9995 | Val Acc: 0.9980
# Epoch 17/30 | Train Acc: 0.9993 | Val Acc: 0.9977
# Epoch 18/30 | Train Acc: 0.9996 | Val Acc: 0.9984
# Epoch 19/30 | Train Acc: 0.9994 | Val Acc: 0.9981
# Epoch 20/30 | Train Acc: 0.9997 | Val Acc: 0.9981
# Early stopping at epoch 20
#
# Results:
#   Test Accuracy: 0.9991
#   Training Time: 365.5s
#
# ============================================================
# Model: LSTM | Dataset: augmented | Seed: 456
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.9469 | Val Acc: 0.9921
# Epoch 2/30 | Train Acc: 0.9903 | Val Acc: 0.9932
# Epoch 3/30 | Train Acc: 0.9938 | Val Acc: 0.9948
# Epoch 4/30 | Train Acc: 0.9948 | Val Acc: 0.9961
# Epoch 5/30 | Train Acc: 0.9966 | Val Acc: 0.9972
# Epoch 6/30 | Train Acc: 0.9977 | Val Acc: 0.9981
# Epoch 7/30 | Train Acc: 0.9980 | Val Acc: 0.9984
# Epoch 8/30 | Train Acc: 0.9983 | Val Acc: 0.9987
# Epoch 9/30 | Train Acc: 0.9985 | Val Acc: 0.9977
# Epoch 10/30 | Train Acc: 0.9988 | Val Acc: 0.9985
# Epoch 11/30 | Train Acc: 0.9993 | Val Acc: 0.9989
# Epoch 12/30 | Train Acc: 0.9990 | Val Acc: 0.9993
# Epoch 13/30 | Train Acc: 0.9991 | Val Acc: 0.9985
# Epoch 14/30 | Train Acc: 0.9991 | Val Acc: 0.9990
# Epoch 15/30 | Train Acc: 0.9994 | Val Acc: 0.9993
# Epoch 16/30 | Train Acc: 0.9995 | Val Acc: 0.9993
# Epoch 17/30 | Train Acc: 0.9995 | Val Acc: 0.9994
# Epoch 18/30 | Train Acc: 0.9995 | Val Acc: 0.9995
# Epoch 19/30 | Train Acc: 0.9998 | Val Acc: 0.9994
# Epoch 20/30 | Train Acc: 0.9995 | Val Acc: 0.9961
# Epoch 21/30 | Train Acc: 0.9995 | Val Acc: 0.9993
# Epoch 22/30 | Train Acc: 0.9999 | Val Acc: 0.9995
# Epoch 23/30 | Train Acc: 0.9996 | Val Acc: 0.9990
# Early stopping at epoch 23
#
# Results:
#   Test Accuracy: 0.9989
#   Training Time: 410.2s
#
# ============================================================
# Model: Transformer | Dataset: augmented | Seed: 42
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.8971 | Val Acc: 0.9339
# Epoch 2/30 | Train Acc: 0.9563 | Val Acc: 0.9829
# Epoch 3/30 | Train Acc: 0.9764 | Val Acc: 0.9917
# Epoch 4/30 | Train Acc: 0.9800 | Val Acc: 0.9913
# Epoch 5/30 | Train Acc: 0.9803 | Val Acc: 0.9877
# Epoch 6/30 | Train Acc: 0.9843 | Val Acc: 0.9903
# Epoch 7/30 | Train Acc: 0.9839 | Val Acc: 0.9889
# Epoch 8/30 | Train Acc: 0.9848 | Val Acc: 0.9857
# Early stopping at epoch 8
#
# Results:
#   Test Accuracy: 0.9856
#   Training Time: 85.0s
#
# ============================================================
# Model: Transformer | Dataset: augmented | Seed: 123
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.9103 | Val Acc: 0.9807
# Epoch 2/30 | Train Acc: 0.9750 | Val Acc: 0.9883
# Epoch 3/30 | Train Acc: 0.9789 | Val Acc: 0.9900
# Epoch 4/30 | Train Acc: 0.9808 | Val Acc: 0.9778
# Epoch 5/30 | Train Acc: 0.9818 | Val Acc: 0.9917
# Epoch 6/30 | Train Acc: 0.9844 | Val Acc: 0.9873
# Epoch 7/30 | Train Acc: 0.9828 | Val Acc: 0.9895
# Epoch 8/30 | Train Acc: 0.9843 | Val Acc: 0.9878
# Epoch 9/30 | Train Acc: 0.9840 | Val Acc: 0.9890
# Epoch 10/30 | Train Acc: 0.9847 | Val Acc: 0.9863
# Early stopping at epoch 10
#
# Results:
#   Test Accuracy: 0.9887
#   Training Time: 108.4s
#
# ============================================================
# Model: Transformer | Dataset: augmented | Seed: 456
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.9246 | Val Acc: 0.9906
# Epoch 2/30 | Train Acc: 0.9752 | Val Acc: 0.9919
# Epoch 3/30 | Train Acc: 0.9776 | Val Acc: 0.9894
# Epoch 4/30 | Train Acc: 0.9804 | Val Acc: 0.9837
# Epoch 5/30 | Train Acc: 0.9821 | Val Acc: 0.9924
# Epoch 6/30 | Train Acc: 0.9824 | Val Acc: 0.9824
# Epoch 7/30 | Train Acc: 0.9836 | Val Acc: 0.9911
# Epoch 8/30 | Train Acc: 0.9848 | Val Acc: 0.9912
# Epoch 9/30 | Train Acc: 0.9854 | Val Acc: 0.9925
# Epoch 10/30 | Train Acc: 0.9856 | Val Acc: 0.9929
# Epoch 11/30 | Train Acc: 0.9865 | Val Acc: 0.9925
# Epoch 12/30 | Train Acc: 0.9849 | Val Acc: 0.9939
# Epoch 13/30 | Train Acc: 0.9871 | Val Acc: 0.9861
# Epoch 14/30 | Train Acc: 0.9867 | Val Acc: 0.9897
# Epoch 15/30 | Train Acc: 0.9869 | Val Acc: 0.9933
# Epoch 16/30 | Train Acc: 0.9870 | Val Acc: 0.9841
# Epoch 17/30 | Train Acc: 0.9877 | Val Acc: 0.9922
# Early stopping at epoch 17
#
# Results:
#   Test Accuracy: 0.9935
#   Training Time: 182.8s
#
# ============================================================
# Model: LSTM | Dataset: hard | Seed: 42
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.8764 | Val Acc: 0.9847
# Epoch 2/30 | Train Acc: 0.9888 | Val Acc: 0.9941
# Epoch 3/30 | Train Acc: 0.9939 | Val Acc: 0.9951
# Epoch 4/30 | Train Acc: 0.9947 | Val Acc: 0.9961
# Epoch 5/30 | Train Acc: 0.9958 | Val Acc: 0.9978
# Epoch 6/30 | Train Acc: 0.9961 | Val Acc: 0.9965
# Epoch 7/30 | Train Acc: 0.9968 | Val Acc: 0.9968
# Epoch 8/30 | Train Acc: 0.9970 | Val Acc: 0.9965
# Epoch 9/30 | Train Acc: 0.9975 | Val Acc: 0.9972
# Epoch 10/30 | Train Acc: 0.9975 | Val Acc: 0.9977
# Early stopping at epoch 10
#
# Results:
#   Test Accuracy: 0.9975
#   Training Time: 233.0s
#   Length Gen Accuracy: 0.9989 (n=33544)
#
# ============================================================
# Model: LSTM | Dataset: hard | Seed: 123
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.8585 | Val Acc: 0.9905
# Epoch 2/30 | Train Acc: 0.9932 | Val Acc: 0.9959
# Epoch 3/30 | Train Acc: 0.9958 | Val Acc: 0.9959
# Epoch 4/30 | Train Acc: 0.9966 | Val Acc: 0.9965
# Epoch 5/30 | Train Acc: 0.9969 | Val Acc: 0.9969
# Epoch 6/30 | Train Acc: 0.9977 | Val Acc: 0.9981
# Epoch 7/30 | Train Acc: 0.9982 | Val Acc: 0.9965
# Epoch 8/30 | Train Acc: 0.9983 | Val Acc: 0.9979
# Epoch 9/30 | Train Acc: 0.9990 | Val Acc: 0.9983
# Epoch 10/30 | Train Acc: 0.9990 | Val Acc: 0.9975
# Epoch 11/30 | Train Acc: 0.9992 | Val Acc: 0.9978
# Epoch 12/30 | Train Acc: 0.9987 | Val Acc: 0.9983
# Epoch 13/30 | Train Acc: 0.9994 | Val Acc: 0.9989
# Epoch 14/30 | Train Acc: 0.9993 | Val Acc: 0.9987
# Epoch 15/30 | Train Acc: 0.9992 | Val Acc: 0.9987
# Epoch 16/30 | Train Acc: 0.9995 | Val Acc: 0.9985
# Epoch 17/30 | Train Acc: 0.9994 | Val Acc: 0.9991
# Epoch 18/30 | Train Acc: 0.9996 | Val Acc: 0.9989
# Epoch 19/30 | Train Acc: 0.9993 | Val Acc: 0.9989
# Epoch 20/30 | Train Acc: 0.9996 | Val Acc: 0.9989
# Epoch 21/30 | Train Acc: 0.9994 | Val Acc: 0.9989
# Epoch 22/30 | Train Acc: 0.9997 | Val Acc: 0.9989
# Early stopping at epoch 22
#
# Results:
#   Test Accuracy: 0.9991
#   Training Time: 512.7s
#   Length Gen Accuracy: 0.9996 (n=33544)
#
# ============================================================
# Model: LSTM | Dataset: hard | Seed: 456
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.8257 | Val Acc: 0.8873
# Epoch 2/30 | Train Acc: 0.9819 | Val Acc: 0.9963
# Epoch 3/30 | Train Acc: 0.9955 | Val Acc: 0.9963
# Epoch 4/30 | Train Acc: 0.9963 | Val Acc: 0.9976
# Epoch 5/30 | Train Acc: 0.9967 | Val Acc: 0.9972
# Epoch 6/30 | Train Acc: 0.9970 | Val Acc: 0.9968
# Epoch 7/30 | Train Acc: 0.9973 | Val Acc: 0.9985
# Epoch 8/30 | Train Acc: 0.9974 | Val Acc: 0.9975
# Epoch 9/30 | Train Acc: 0.9981 | Val Acc: 0.9986
# Epoch 10/30 | Train Acc: 0.9984 | Val Acc: 0.9977
# Epoch 11/30 | Train Acc: 0.9982 | Val Acc: 0.9982
# Epoch 12/30 | Train Acc: 0.9984 | Val Acc: 0.9983
# Epoch 13/30 | Train Acc: 0.9984 | Val Acc: 0.9987
# Epoch 14/30 | Train Acc: 0.9987 | Val Acc: 0.9985
# Epoch 15/30 | Train Acc: 0.9988 | Val Acc: 0.9981
# Epoch 16/30 | Train Acc: 0.9992 | Val Acc: 0.9987
# Epoch 17/30 | Train Acc: 0.9993 | Val Acc: 0.9983
# Epoch 18/30 | Train Acc: 0.9986 | Val Acc: 0.9981
# Early stopping at epoch 18
#
# Results:
#   Test Accuracy: 0.9977
#   Training Time: 420.3s
#   Length Gen Accuracy: 0.9993 (n=33544)
#
# ============================================================
# Model: Transformer | Dataset: hard | Seed: 42
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.7860 | Val Acc: 0.8792
# Epoch 2/30 | Train Acc: 0.9005 | Val Acc: 0.9496
# Epoch 3/30 | Train Acc: 0.9243 | Val Acc: 0.9303
# Epoch 4/30 | Train Acc: 0.9436 | Val Acc: 0.9114
# Epoch 5/30 | Train Acc: 0.9549 | Val Acc: 0.9519
# Epoch 6/30 | Train Acc: 0.9705 | Val Acc: 0.9583
# Epoch 7/30 | Train Acc: 0.9834 | Val Acc: 0.9777
# Epoch 8/30 | Train Acc: 0.9805 | Val Acc: 0.9907
# Epoch 9/30 | Train Acc: 0.9880 | Val Acc: 0.9915
# Epoch 10/30 | Train Acc: 0.9860 | Val Acc: 0.9931
# Epoch 11/30 | Train Acc: 0.9891 | Val Acc: 0.9941
# Epoch 12/30 | Train Acc: 0.9526 | Val Acc: 0.9769
# Epoch 13/30 | Train Acc: 0.9804 | Val Acc: 0.9908
# Epoch 14/30 | Train Acc: 0.9804 | Val Acc: 0.9841
# Epoch 15/30 | Train Acc: 0.9863 | Val Acc: 0.9923
# Epoch 16/30 | Train Acc: 0.9882 | Val Acc: 0.9915
# Early stopping at epoch 16
#
# Results:
#   Test Accuracy: 0.9924
#   Training Time: 179.8s
#   Length Gen Accuracy: 0.9928 (n=33544)
#
# ============================================================
# Model: Transformer | Dataset: hard | Seed: 123
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.7927 | Val Acc: 0.9355
# Epoch 2/30 | Train Acc: 0.9574 | Val Acc: 0.9744
# Epoch 3/30 | Train Acc: 0.9713 | Val Acc: 0.9744
# Epoch 4/30 | Train Acc: 0.9725 | Val Acc: 0.9744
# Epoch 5/30 | Train Acc: 0.9736 | Val Acc: 0.9747
# Epoch 6/30 | Train Acc: 0.9719 | Val Acc: 0.9744
# Epoch 7/30 | Train Acc: 0.9746 | Val Acc: 0.9766
# Epoch 8/30 | Train Acc: 0.9748 | Val Acc: 0.9768
# Epoch 9/30 | Train Acc: 0.9747 | Val Acc: 0.9765
# Epoch 10/30 | Train Acc: 0.9755 | Val Acc: 0.9766
# Epoch 11/30 | Train Acc: 0.9750 | Val Acc: 0.9768
# Epoch 12/30 | Train Acc: 0.9763 | Val Acc: 0.9757
# Epoch 13/30 | Train Acc: 0.9761 | Val Acc: 0.9766
# Early stopping at epoch 13
#
# Results:
#   Test Accuracy: 0.9766
#   Training Time: 145.7s
#   Length Gen Accuracy: 0.9778 (n=33544)
#
# ============================================================
# Model: Transformer | Dataset: hard | Seed: 456
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.8015 | Val Acc: 0.9631
# Epoch 2/30 | Train Acc: 0.9503 | Val Acc: 0.9757
# Epoch 3/30 | Train Acc: 0.9718 | Val Acc: 0.9872
# Epoch 4/30 | Train Acc: 0.9811 | Val Acc: 0.9909
# Epoch 5/30 | Train Acc: 0.9850 | Val Acc: 0.9905
# Epoch 6/30 | Train Acc: 0.9796 | Val Acc: 0.9763
# Epoch 7/30 | Train Acc: 0.9758 | Val Acc: 0.9872
# Epoch 8/30 | Train Acc: 0.9847 | Val Acc: 0.9909
# Epoch 9/30 | Train Acc: 0.9869 | Val Acc: 0.9931
# Epoch 10/30 | Train Acc: 0.9484 | Val Acc: 0.9763
# Epoch 11/30 | Train Acc: 0.9658 | Val Acc: 0.9763
# Epoch 12/30 | Train Acc: 0.9710 | Val Acc: 0.9763
# Epoch 13/30 | Train Acc: 0.9712 | Val Acc: 0.9763
# Epoch 14/30 | Train Acc: 0.9732 | Val Acc: 0.9813
# Early stopping at epoch 14
#
# Results:
#   Test Accuracy: 0.9797
#   Training Time: 156.1s
#   Length Gen Accuracy: 0.9816 (n=33544)
#
# ============================================================
# ALL EXPERIMENTS COMPLETE
# ============================================================

# %%
# %% CELL 15: Save Final Results
results_df = pd.DataFrame(all_results)
results_df.to_csv(f'{OUTPUT_DIR}/b3_results.csv', index=False)
print(f"Results saved to {OUTPUT_DIR}/b3_results.csv")

print("\n" + "="*60)
print("SUMMARY TABLE")
print("="*60)
print(results_df.to_string(index=False))

# %% CELL 16: Summary Statistics
summary = results_df.groupby(['model', 'dataset']).agg({
    'test_acc': ['mean', 'std'],
    'train_time': 'mean'
}).round(4)

print("\n" + "="*60)
print("AGGREGATED RESULTS (mean ± std)")
print("="*60)
print(summary)

summary.to_csv(f'{OUTPUT_DIR}/b3_summary.csv')

# %% CELL 17: Visualization
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

pivot = results_df.pivot_table(values='test_acc', index='dataset', columns='model', aggfunc='mean')
pivot.plot(kind='bar', ax=axes[0], rot=0)
axes[0].set_title('B₃ Word Problem: Test Accuracy')
axes[0].set_ylabel('Accuracy')
axes[0].set_ylim(0.5, 1.0)
axes[0].legend(title='Model')

pivot_time = results_df.pivot_table(values='train_time', index='dataset', columns='model', aggfunc='mean')
pivot_time.plot(kind='bar', ax=axes[1], rot=0)
axes[1].set_title('B₃ Word Problem: Training Time')
axes[1].set_ylabel('Seconds')
axes[1].legend(title='Model')

plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/b3_results.png', dpi=150)
plt.show()

print(f"\nVisualization saved to {OUTPUT_DIR}/b3_results.png")
# Out:
# Results saved to /content/drive/MyDrive/word_problem_results/B3/b3_results.csv
#
# ============================================================
# SUMMARY TABLE
# ============================================================
#       model   dataset  seed  test_acc  val_acc  train_time  len_gen_acc  len_gen_count  epochs
#        LSTM synthetic    42  0.998867 0.998400  271.727291          NaN              0      15
#        LSTM synthetic   123  0.998733 0.999200  289.873324          NaN              0      16
#        LSTM synthetic   456  0.998667 0.998733  216.581429          NaN              0      12
# Transformer synthetic    42  0.986467 0.992733  137.407464          NaN              0      13
# Transformer synthetic   123  0.990467 0.991467   84.633538          NaN              0       8
# Transformer synthetic   456  0.991000 0.991333  168.682841          NaN              0      16
#        LSTM augmented    42  0.998800 0.999067  375.076211          NaN              0      21
#        LSTM augmented   123  0.999067 0.998600  365.509300          NaN              0      20
#        LSTM augmented   456  0.998867 0.999467  410.168042          NaN              0      23
# Transformer augmented    42  0.985600 0.991667   84.980860          NaN              0       8
# Transformer augmented   123  0.988733 0.991733  108.394969          NaN              0      10
# Transformer augmented   456  0.993467 0.993933  182.783396          NaN              0      17
#        LSTM      hard    42  0.997467 0.997800  232.958403     0.998867          33544      10
#        LSTM      hard   123  0.999067 0.999067  512.742745     0.999642          33544      22
#        LSTM      hard   456  0.997733 0.998733  420.276212     0.999255          33544      18
# Transformer      hard    42  0.992400 0.994067  179.811792     0.992756          33544      16
# Transformer      hard   123  0.976600 0.976800  145.665012     0.977790          33544      13
# Transformer      hard   456  0.979733 0.993067  156.111257     0.981636          33544      14
#
# ============================================================
# AGGREGATED RESULTS (mean ± std)
# ============================================================
#                       test_acc         train_time
#                           mean     std       mean
# model       dataset
# LSTM        augmented   0.9989  0.0001   383.5845
#             hard        0.9981  0.0009   388.6591
#             synthetic   0.9988  0.0001   259.3940
# Transformer augmented   0.9893  0.0040   125.3864
#             hard        0.9829  0.0084   160.5294
#             synthetic   0.9893  0.0025   130.2413
# Visualization saved to /content/drive/MyDrive/word_problem_results/B3/b3_results.png
