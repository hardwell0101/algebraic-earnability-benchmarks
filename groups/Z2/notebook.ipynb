# %%
# %% CELL 1: Setup and Imports
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from sklearn.model_selection import train_test_split
import time
import os

# Check GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")
if device.type == 'cuda':
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Device: cuda
# GPU: NVIDIA L4

# %%
# %% CELL 2: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Create output directory
OUTPUT_DIR = '/content/drive/MyDrive/word_problem_results/Z2'
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Results will be saved to: {OUTPUT_DIR}")

# %% CELL 3: Set Data Directory
DATA_DIR = '/content/Z2'

df_synthetic = pd.read_csv(os.path.join(DATA_DIR, 'z2_synthetic_100k.csv'))
df_augmented = pd.read_csv(os.path.join(DATA_DIR, 'z2_anbn_100k.csv'))
df_hard = pd.read_csv(os.path.join(DATA_DIR, 'z2_hard_100k.csv'))

datasets = {
    'synthetic': df_synthetic,
    'anbn': df_augmented,
    'hard': df_hard
}

for name, df in datasets.items():
    print(f"{name}: {len(df)} rows, {df['label'].sum()} identity, {len(df) - df['label'].sum()} non-identity")
# %% CELL 5: Quick Data Check
print(f"\nSynthetic: {len(df_synthetic)} rows")
print(f"Anbn: {len(df_augmented)} rows")
print(f"Tomita5: {len(df_hard)} rows")
print(df_synthetic.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Results will be saved to: /content/drive/MyDrive/word_problem_results/Z2
# synthetic: 100000 rows, 50000 identity, 50000 non-identity
# anbn: 100000 rows, 50000 identity, 50000 non-identity
# hard: 100000 rows, 50000 identity, 50000 non-identity
#
# Synthetic: 100000 rows
# Anbn: 100000 rows
# Tomita5: 100000 rows
#                                        word  label  length        source
# 0                            bBBBbBabbbABbB      1      14  z2_synthetic
# 1                                 aBabAAbba      0       9  z2_synthetic
# 2  AaaAbAaAaaaAaAaaaBAaaAAbBBAaBbAAAAAbaBba      1      40  z2_synthetic
# 3               aAABAbBBaBaBABAbAAaBAbaabaB      0      27  z2_synthetic
# 4                    AAaAaBbBbAaBBAaaAaBAaa      0      22  z2_synthetic

# %%
# %% CELL 6: Tokenizer
# Z2 uses different alphabets per dataset - detect automatically
def build_vocab(df):
    """Build vocabulary from dataset"""
    all_chars = set()
    for word in df['word'].head(1000):  # Sample for speed
        all_chars.update(word)
    vocab = {'<PAD>': 0}
    for i, c in enumerate(sorted(all_chars)):
        vocab[c] = i + 1
    return vocab

# Build vocab from synthetic (main dataset)
sample_word = df_synthetic['word'].iloc[0]
if ' ' in sample_word:
    # Space-separated tokens
    VOCAB = {'<PAD>': 0}
    all_tokens = set()
    for word in df_synthetic['word'].head(1000):
        all_tokens.update(word.split())
    for i, t in enumerate(sorted(all_tokens)):
        VOCAB[t] = i + 1
    def encode(word):
        return [VOCAB.get(t, 0) for t in word.split()]
else:
    # Character-based
    VOCAB = build_vocab(df_synthetic)
    def encode(word):
        return [VOCAB.get(c, 0) for c in word]

VOCAB_SIZE = len(VOCAB)
print(f"Vocab ({VOCAB_SIZE} tokens): {VOCAB}")
print(f"encode('{sample_word[:20]}') = {encode(sample_word[:20])}")

# %% CELL 7: Dataset Class
class WordProblemDataset(Dataset):
    def __init__(self, words, labels):
        self.words = words
        self.labels = labels

    def __len__(self):
        return len(self.words)

    def __getitem__(self, idx):
        encoded = encode(self.words[idx])
        return encoded, self.labels[idx], len(encoded)

def collate_fn(batch):
    words, labels, lengths = zip(*batch)
    max_len = max(lengths)

    padded = []
    for w in words:
        padded.append(w + [0] * (max_len - len(w)))

    sorted_indices = sorted(range(len(lengths)), key=lambda i: lengths[i], reverse=True)

    padded_sorted = [padded[i] for i in sorted_indices]
    labels_sorted = [labels[i] for i in sorted_indices]
    lengths_sorted = [lengths[i] for i in sorted_indices]

    return (
        torch.tensor(padded_sorted),
        torch.tensor(labels_sorted, dtype=torch.float),
        torch.tensor(lengths_sorted)
    )

# %% CELL 8: LSTM Model
class LSTMClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim=64, hidden_dim=128,
                 num_layers=2, dropout=0.3, bidirectional=True):
        super().__init__()
        self.bidirectional = bidirectional

        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)

        self.lstm = nn.LSTM(
            input_size=embed_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0,
            bidirectional=bidirectional
        )

        lstm_output_dim = hidden_dim * 2 if bidirectional else hidden_dim

        self.classifier = nn.Sequential(
            nn.Linear(lstm_output_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, 1)
        )

    def forward(self, input_ids, lengths):
        embedded = self.embedding(input_ids)
        packed = pack_padded_sequence(embedded, lengths.cpu(), batch_first=True, enforce_sorted=True)
        _, (hidden, _) = self.lstm(packed)

        if self.bidirectional:
            hidden = torch.cat([hidden[-2], hidden[-1]], dim=1)
        else:
            hidden = hidden[-1]

        return self.classifier(hidden).squeeze(-1)

# %% CELL 9: Transformer Model
class TransformerClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim=64, num_heads=4,
                 num_layers=2, dropout=0.3, max_len=200):
        super().__init__()

        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.pos_encoding = nn.Embedding(max_len, embed_dim)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=embed_dim,
            nhead=num_heads,
            dim_feedforward=embed_dim * 4,
            dropout=dropout,
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        self.classifier = nn.Sequential(
            nn.Linear(embed_dim, embed_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(embed_dim, 1)
        )

    def forward(self, input_ids, lengths):
        batch_size, seq_len = input_ids.shape

        positions = torch.arange(seq_len, device=input_ids.device).unsqueeze(0).expand(batch_size, -1)
        embedded = self.embedding(input_ids) + self.pos_encoding(positions)

        mask = (input_ids == 0)

        output = self.transformer(embedded, src_key_padding_mask=mask)

        mask_expanded = (~mask).unsqueeze(-1).float()
        pooled = (output * mask_expanded).sum(dim=1) / mask_expanded.sum(dim=1).clamp(min=1)

        return self.classifier(pooled).squeeze(-1)

print("Models defined: LSTMClassifier, TransformerClassifier")

# %% CELL 10: Training Function
def train_model(model, train_loader, val_loader, epochs=30, patience=5, lr=0.001):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()

    best_val_acc = 0
    best_model_state = None
    patience_counter = 0
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

    for epoch in range(epochs):
        model.train()
        train_loss, train_correct, train_total = 0, 0, 0

        for input_ids, labels, lengths in train_loader:
            input_ids, labels, lengths = input_ids.to(device), labels.to(device), lengths.to(device)

            optimizer.zero_grad()
            outputs = model(input_ids, lengths)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            preds = (torch.sigmoid(outputs) > 0.5).float()
            train_correct += (preds == labels).sum().item()
            train_total += labels.size(0)

        train_acc = train_correct / train_total

        model.eval()
        val_loss, val_correct, val_total = 0, 0, 0

        with torch.no_grad():
            for input_ids, labels, lengths in val_loader:
                input_ids, labels, lengths = input_ids.to(device), labels.to(device), lengths.to(device)
                outputs = model(input_ids, lengths)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                preds = (torch.sigmoid(outputs) > 0.5).float()
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        val_acc = val_correct / val_total

        history['train_loss'].append(train_loss / len(train_loader))
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss / len(val_loader))
        history['val_acc'].append(val_acc)

        print(f"Epoch {epoch+1}/{epochs} | Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model_state = model.state_dict().copy()
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

    if best_model_state:
        model.load_state_dict(best_model_state)

    return history, best_val_acc

# %% CELL 11: Evaluation Function
def evaluate_model(model, test_loader):
    model.eval()
    correct, total = 0, 0
    all_preds, all_labels = [], []

    with torch.no_grad():
        for input_ids, labels, lengths in test_loader:
            input_ids, labels, lengths = input_ids.to(device), labels.to(device), lengths.to(device)
            outputs = model(input_ids, lengths)
            preds = (torch.sigmoid(outputs) > 0.5).float()

            correct += (preds == labels).sum().item()
            total += labels.size(0)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = correct / total
    return accuracy, all_preds, all_labels

# %% CELL 12: Length Generalization Test
def test_length_generalization(model, df, train_max_len=50):
    long_df = df[df['length'] > train_max_len].copy()
    if len(long_df) == 0:
        return None, 0

    dataset = WordProblemDataset(long_df['word'].tolist(), long_df['label'].tolist())
    loader = DataLoader(dataset, batch_size=64, collate_fn=collate_fn)

    acc, _, _ = evaluate_model(model, loader)
    return acc, len(long_df)

# %% CELL 13: Run Single Experiment
def run_experiment(df, model_type, seed, dataset_name):
    print(f"\n{'='*60}")
    print(f"Model: {model_type} | Dataset: {dataset_name} | Seed: {seed}")
    print(f"{'='*60}")

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)

    train_df, temp_df = train_test_split(df, test_size=0.3, random_state=seed)
    val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=seed)

    train_dataset = WordProblemDataset(train_df['word'].tolist(), train_df['label'].tolist())
    val_dataset = WordProblemDataset(val_df['word'].tolist(), val_df['label'].tolist())
    test_dataset = WordProblemDataset(test_df['word'].tolist(), test_df['label'].tolist())

    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, collate_fn=collate_fn)
    val_loader = DataLoader(val_dataset, batch_size=64, collate_fn=collate_fn)
    test_loader = DataLoader(test_dataset, batch_size=64, collate_fn=collate_fn)

    print(f"Train: {len(train_dataset)} | Val: {len(val_dataset)} | Test: {len(test_dataset)}")

    if model_type == 'LSTM':
        model = LSTMClassifier(VOCAB_SIZE).to(device)
    else:
        model = TransformerClassifier(VOCAB_SIZE).to(device)

    params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"Parameters: {params:,}")

    start_time = time.time()
    history, best_val_acc = train_model(model, train_loader, val_loader)
    train_time = time.time() - start_time

    test_acc, _, _ = evaluate_model(model, test_loader)

    len_gen_acc, len_gen_count = test_length_generalization(model, df)

    print(f"\nResults:")
    print(f"  Test Accuracy: {test_acc:.4f}")
    print(f"  Training Time: {train_time:.1f}s")
    if len_gen_acc:
        print(f"  Length Gen Accuracy: {len_gen_acc:.4f} (n={len_gen_count})")

    return {
        'model': model_type,
        'dataset': dataset_name,
        'seed': seed,
        'test_acc': test_acc,
        'val_acc': best_val_acc,
        'train_time': train_time,
        'len_gen_acc': len_gen_acc,
        'len_gen_count': len_gen_count,
        'epochs': len(history['train_acc'])
    }
# Out:
# Vocab (5 tokens): {'<PAD>': 0, 'A': 1, 'B': 2, 'a': 3, 'b': 4}
# encode('bBBBbBabbbABbB') = [4, 2, 2, 2, 4, 2, 3, 4, 4, 4, 1, 2, 4, 2]
# Models defined: LSTMClassifier, TransformerClassifier

# %%
# %% CELL 14: Run All Experiments
SEEDS = [42, 123, 456]
MODEL_TYPES = ['LSTM', 'Transformer']
DATASET_NAMES = ['synthetic', 'anbn', 'hard']

all_results = []

for dataset_name in DATASET_NAMES:
    df = datasets[dataset_name]
    for model_type in MODEL_TYPES:
        for seed in SEEDS:
            result = run_experiment(df, model_type, seed, dataset_name)
            all_results.append(result)

            results_df = pd.DataFrame(all_results)
            results_df.to_csv(f'{OUTPUT_DIR}/z2_results_partial.csv', index=False)

print("\n" + "="*60)
print("ALL EXPERIMENTS COMPLETE")
print("="*60)
# Out:
# ============================================================
# Model: LSTM | Dataset: synthetic | Seed: 42
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.9129 | Val Acc: 0.9975
# Epoch 2/30 | Train Acc: 0.9986 | Val Acc: 0.9999
# Epoch 3/30 | Train Acc: 0.9993 | Val Acc: 0.9992
# Epoch 4/30 | Train Acc: 0.9994 | Val Acc: 1.0000
# Epoch 5/30 | Train Acc: 0.9998 | Val Acc: 1.0000
# Epoch 6/30 | Train Acc: 0.9996 | Val Acc: 1.0000
# Epoch 7/30 | Train Acc: 0.9996 | Val Acc: 1.0000
# Epoch 8/30 | Train Acc: 0.9999 | Val Acc: 1.0000
# Epoch 9/30 | Train Acc: 0.9999 | Val Acc: 1.0000
# Early stopping at epoch 9
#
# Results:
#   Test Accuracy: 1.0000
#   Training Time: 157.3s
#
# ============================================================
# Model: LSTM | Dataset: synthetic | Seed: 123
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.9273 | Val Acc: 0.9998
# Epoch 2/30 | Train Acc: 0.9984 | Val Acc: 0.9999
# Epoch 3/30 | Train Acc: 0.9994 | Val Acc: 0.9997
# Epoch 4/30 | Train Acc: 0.9997 | Val Acc: 1.0000
# Epoch 5/30 | Train Acc: 0.9994 | Val Acc: 0.9997
# Epoch 6/30 | Train Acc: 0.9998 | Val Acc: 1.0000
# Epoch 7/30 | Train Acc: 1.0000 | Val Acc: 1.0000
# Epoch 8/30 | Train Acc: 0.9997 | Val Acc: 1.0000
# Epoch 9/30 | Train Acc: 0.9999 | Val Acc: 1.0000
# Early stopping at epoch 9
#
# Results:
#   Test Accuracy: 1.0000
#   Training Time: 156.7s
#
# ============================================================
# Model: LSTM | Dataset: synthetic | Seed: 456
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.9226 | Val Acc: 0.9982
# Epoch 2/30 | Train Acc: 0.9981 | Val Acc: 0.9998
# Epoch 3/30 | Train Acc: 0.9988 | Val Acc: 0.9999
# Epoch 4/30 | Train Acc: 0.9996 | Val Acc: 1.0000
# Epoch 5/30 | Train Acc: 0.9995 | Val Acc: 1.0000
# Epoch 6/30 | Train Acc: 0.9997 | Val Acc: 1.0000
# Epoch 7/30 | Train Acc: 0.9995 | Val Acc: 1.0000
# Epoch 8/30 | Train Acc: 0.9998 | Val Acc: 1.0000
# Epoch 9/30 | Train Acc: 0.9996 | Val Acc: 1.0000
# Early stopping at epoch 9
#
# Results:
#   Test Accuracy: 1.0000
#   Training Time: 156.6s
#
# ============================================================
# Model: Transformer | Dataset: synthetic | Seed: 42
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.8890 | Val Acc: 0.9379
# Epoch 2/30 | Train Acc: 0.9641 | Val Acc: 0.9844
# Epoch 3/30 | Train Acc: 0.9861 | Val Acc: 0.9883
# Epoch 4/30 | Train Acc: 0.9888 | Val Acc: 0.9963
# Epoch 5/30 | Train Acc: 0.9899 | Val Acc: 0.9949
# Epoch 6/30 | Train Acc: 0.9903 | Val Acc: 0.9965
# Epoch 7/30 | Train Acc: 0.9912 | Val Acc: 0.9977
# Epoch 8/30 | Train Acc: 0.9916 | Val Acc: 0.9952
# Epoch 9/30 | Train Acc: 0.9922 | Val Acc: 0.9959
# Epoch 10/30 | Train Acc: 0.9929 | Val Acc: 0.9969
# Epoch 11/30 | Train Acc: 0.9927 | Val Acc: 0.9961
# Epoch 12/30 | Train Acc: 0.9938 | Val Acc: 0.9987
# Epoch 13/30 | Train Acc: 0.9934 | Val Acc: 0.9988
# Epoch 14/30 | Train Acc: 0.9938 | Val Acc: 0.9991
# Epoch 15/30 | Train Acc: 0.9940 | Val Acc: 0.9953
# Epoch 16/30 | Train Acc: 0.9944 | Val Acc: 0.9984
# Epoch 17/30 | Train Acc: 0.9943 | Val Acc: 0.9993
# Epoch 18/30 | Train Acc: 0.9952 | Val Acc: 0.9975
# Epoch 19/30 | Train Acc: 0.9955 | Val Acc: 0.9992
# Epoch 20/30 | Train Acc: 0.9953 | Val Acc: 0.9982
# Epoch 21/30 | Train Acc: 0.9955 | Val Acc: 0.9993
# Epoch 22/30 | Train Acc: 0.9960 | Val Acc: 0.9991
# Early stopping at epoch 22
#
# Results:
#   Test Accuracy: 0.9997
#   Training Time: 210.2s
#
# ============================================================
# Model: Transformer | Dataset: synthetic | Seed: 123
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.8442 | Val Acc: 0.9363
# Epoch 2/30 | Train Acc: 0.9508 | Val Acc: 0.9899
# Epoch 3/30 | Train Acc: 0.9852 | Val Acc: 0.9920
# Epoch 4/30 | Train Acc: 0.9885 | Val Acc: 0.9981
# Epoch 5/30 | Train Acc: 0.9898 | Val Acc: 0.9983
# Epoch 6/30 | Train Acc: 0.9906 | Val Acc: 0.9965
# Epoch 7/30 | Train Acc: 0.9917 | Val Acc: 0.9929
# Epoch 8/30 | Train Acc: 0.9923 | Val Acc: 0.9971
# Epoch 9/30 | Train Acc: 0.9929 | Val Acc: 0.9957
# Epoch 10/30 | Train Acc: 0.9936 | Val Acc: 0.9965
# Early stopping at epoch 10
#
# Results:
#   Test Accuracy: 0.9958
#   Training Time: 96.0s
#
# ============================================================
# Model: Transformer | Dataset: synthetic | Seed: 456
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.8556 | Val Acc: 0.9788
# Epoch 2/30 | Train Acc: 0.9832 | Val Acc: 0.9983
# Epoch 3/30 | Train Acc: 0.9868 | Val Acc: 0.9964
# Epoch 4/30 | Train Acc: 0.9889 | Val Acc: 0.9979
# Epoch 5/30 | Train Acc: 0.9910 | Val Acc: 0.9976
# Epoch 6/30 | Train Acc: 0.9906 | Val Acc: 0.9976
# Epoch 7/30 | Train Acc: 0.9908 | Val Acc: 0.9971
# Early stopping at epoch 7
#
# Results:
#   Test Accuracy: 0.9963
#   Training Time: 67.0s
#
# ============================================================
# Model: LSTM | Dataset: anbn | Seed: 42
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.9739 | Val Acc: 0.9956
# Epoch 2/30 | Train Acc: 0.9989 | Val Acc: 0.9989
# Epoch 3/30 | Train Acc: 0.9994 | Val Acc: 1.0000
# Epoch 4/30 | Train Acc: 1.0000 | Val Acc: 1.0000
# Epoch 5/30 | Train Acc: 1.0000 | Val Acc: 1.0000
# Epoch 6/30 | Train Acc: 0.9993 | Val Acc: 1.0000
# Epoch 7/30 | Train Acc: 1.0000 | Val Acc: 1.0000
# Epoch 8/30 | Train Acc: 0.9997 | Val Acc: 1.0000
# Early stopping at epoch 8
#
# Results:
#   Test Accuracy: 1.0000
#   Training Time: 136.8s
#
# ============================================================
# Model: LSTM | Dataset: anbn | Seed: 123
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.9749 | Val Acc: 0.9972
# Epoch 2/30 | Train Acc: 0.9987 | Val Acc: 1.0000
# Epoch 3/30 | Train Acc: 0.9999 | Val Acc: 1.0000
# Epoch 4/30 | Train Acc: 1.0000 | Val Acc: 1.0000
# Epoch 5/30 | Train Acc: 1.0000 | Val Acc: 1.0000
# Epoch 6/30 | Train Acc: 0.9989 | Val Acc: 1.0000
# Epoch 7/30 | Train Acc: 1.0000 | Val Acc: 1.0000
# Early stopping at epoch 7
#
# Results:
#   Test Accuracy: 1.0000
#   Training Time: 119.1s
#
# ============================================================
# Model: LSTM | Dataset: anbn | Seed: 456
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.9771 | Val Acc: 0.9993
# Epoch 2/30 | Train Acc: 0.9984 | Val Acc: 1.0000
# Epoch 3/30 | Train Acc: 0.9998 | Val Acc: 1.0000
# Epoch 4/30 | Train Acc: 0.9995 | Val Acc: 1.0000
# Epoch 5/30 | Train Acc: 1.0000 | Val Acc: 1.0000
# Epoch 6/30 | Train Acc: 0.9998 | Val Acc: 1.0000
# Epoch 7/30 | Train Acc: 1.0000 | Val Acc: 1.0000
# Early stopping at epoch 7
#
# Results:
#   Test Accuracy: 1.0000
#   Training Time: 119.6s
#
# ============================================================
# Model: Transformer | Dataset: anbn | Seed: 42
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.9694 | Val Acc: 0.9946
# Epoch 2/30 | Train Acc: 0.9836 | Val Acc: 0.9914
# Epoch 3/30 | Train Acc: 0.9864 | Val Acc: 0.9927
# Epoch 4/30 | Train Acc: 0.9869 | Val Acc: 0.9986
# Epoch 5/30 | Train Acc: 0.9890 | Val Acc: 0.9939
# Epoch 6/30 | Train Acc: 0.9897 | Val Acc: 0.9919
# Epoch 7/30 | Train Acc: 0.9908 | Val Acc: 0.9956
# Epoch 8/30 | Train Acc: 0.9926 | Val Acc: 0.9896
# Epoch 9/30 | Train Acc: 0.9944 | Val Acc: 0.9928
# Early stopping at epoch 9
#
# Results:
#   Test Accuracy: 0.9917
#   Training Time: 86.6s
#
# ============================================================
# Model: Transformer | Dataset: anbn | Seed: 123
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.9645 | Val Acc: 0.9873
# Epoch 2/30 | Train Acc: 0.9821 | Val Acc: 0.9895
# Epoch 3/30 | Train Acc: 0.9848 | Val Acc: 0.9932
# Epoch 4/30 | Train Acc: 0.9857 | Val Acc: 0.9907
# Epoch 5/30 | Train Acc: 0.9880 | Val Acc: 0.9966
# Epoch 6/30 | Train Acc: 0.9893 | Val Acc: 0.9989
# Epoch 7/30 | Train Acc: 0.9905 | Val Acc: 0.9928
# Epoch 8/30 | Train Acc: 0.9922 | Val Acc: 0.9979
# Epoch 9/30 | Train Acc: 0.9919 | Val Acc: 0.9939
# Epoch 10/30 | Train Acc: 0.9945 | Val Acc: 0.9965
# Epoch 11/30 | Train Acc: 0.9948 | Val Acc: 0.9957
# Early stopping at epoch 11
#
# Results:
#   Test Accuracy: 0.9958
#   Training Time: 105.9s
#
# ============================================================
# Model: Transformer | Dataset: anbn | Seed: 456
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.9664 | Val Acc: 0.9949
# Epoch 2/30 | Train Acc: 0.9820 | Val Acc: 0.9897
# Epoch 3/30 | Train Acc: 0.9845 | Val Acc: 0.9961
# Epoch 4/30 | Train Acc: 0.9867 | Val Acc: 0.9885
# Epoch 5/30 | Train Acc: 0.9891 | Val Acc: 0.9957
# Epoch 6/30 | Train Acc: 0.9917 | Val Acc: 0.9931
# Epoch 7/30 | Train Acc: 0.9932 | Val Acc: 0.9948
# Epoch 8/30 | Train Acc: 0.9925 | Val Acc: 0.9955
# Early stopping at epoch 8
#
# Results:
#   Test Accuracy: 0.9947
#   Training Time: 76.8s
#
# ============================================================
# Model: LSTM | Dataset: hard | Seed: 42
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.6173 | Val Acc: 0.6396
# Epoch 2/30 | Train Acc: 0.6362 | Val Acc: 0.6258
# Epoch 3/30 | Train Acc: 0.6368 | Val Acc: 0.6448
# Epoch 4/30 | Train Acc: 0.6382 | Val Acc: 0.6591
# Epoch 5/30 | Train Acc: 0.8253 | Val Acc: 0.8624
# Epoch 6/30 | Train Acc: 0.9669 | Val Acc: 1.0000
# Epoch 7/30 | Train Acc: 0.9982 | Val Acc: 1.0000
# Epoch 8/30 | Train Acc: 0.9988 | Val Acc: 1.0000
# Epoch 9/30 | Train Acc: 0.9993 | Val Acc: 1.0000
# Epoch 10/30 | Train Acc: 0.9992 | Val Acc: 0.9999
# Epoch 11/30 | Train Acc: 0.9993 | Val Acc: 1.0000
# Early stopping at epoch 11
#
# Results:
#   Test Accuracy: 1.0000
#   Training Time: 292.2s
#   Length Gen Accuracy: 1.0000 (n=61689)
#
# ============================================================
# Model: LSTM | Dataset: hard | Seed: 123
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.6004 | Val Acc: 0.6247
# Epoch 2/30 | Train Acc: 0.6369 | Val Acc: 0.6338
# Epoch 3/30 | Train Acc: 0.6394 | Val Acc: 0.6306
# Epoch 4/30 | Train Acc: 0.6407 | Val Acc: 0.6367
# Epoch 5/30 | Train Acc: 0.6415 | Val Acc: 0.6395
# Epoch 6/30 | Train Acc: 0.6433 | Val Acc: 0.6397
# Epoch 7/30 | Train Acc: 0.6933 | Val Acc: 0.8595
# Epoch 8/30 | Train Acc: 0.9405 | Val Acc: 0.9974
# Epoch 9/30 | Train Acc: 0.9925 | Val Acc: 0.9992
# Epoch 10/30 | Train Acc: 0.9961 | Val Acc: 0.9999
# Epoch 11/30 | Train Acc: 0.9985 | Val Acc: 1.0000
# Epoch 12/30 | Train Acc: 0.9996 | Val Acc: 1.0000
# Epoch 13/30 | Train Acc: 0.9994 | Val Acc: 1.0000
# Epoch 14/30 | Train Acc: 0.9998 | Val Acc: 1.0000
# Epoch 15/30 | Train Acc: 0.9998 | Val Acc: 1.0000
# Epoch 16/30 | Train Acc: 0.9995 | Val Acc: 1.0000
# Early stopping at epoch 16
#
# Results:
#   Test Accuracy: 1.0000
#   Training Time: 427.1s
#   Length Gen Accuracy: 1.0000 (n=61689)
#
# ============================================================
# Model: LSTM | Dataset: hard | Seed: 456
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 627,265
# Epoch 1/30 | Train Acc: 0.6222 | Val Acc: 0.6371
# Epoch 2/30 | Train Acc: 0.6391 | Val Acc: 0.6390
# Epoch 3/30 | Train Acc: 0.7468 | Val Acc: 0.9357
# Epoch 4/30 | Train Acc: 0.9357 | Val Acc: 0.9385
# Epoch 5/30 | Train Acc: 0.9379 | Val Acc: 0.9337
# Epoch 6/30 | Train Acc: 0.9382 | Val Acc: 0.9385
# Epoch 7/30 | Train Acc: 0.9392 | Val Acc: 0.9359
# Epoch 8/30 | Train Acc: 0.9391 | Val Acc: 0.9363
# Epoch 9/30 | Train Acc: 0.9395 | Val Acc: 0.9385
# Epoch 10/30 | Train Acc: 0.9794 | Val Acc: 1.0000
# Epoch 11/30 | Train Acc: 0.9988 | Val Acc: 1.0000
# Epoch 12/30 | Train Acc: 0.9992 | Val Acc: 1.0000
# Epoch 13/30 | Train Acc: 0.9994 | Val Acc: 1.0000
# Epoch 14/30 | Train Acc: 0.9995 | Val Acc: 1.0000
# Epoch 15/30 | Train Acc: 0.9996 | Val Acc: 1.0000
# Early stopping at epoch 15
#
# Results:
#   Test Accuracy: 1.0000
#   Training Time: 398.4s
#   Length Gen Accuracy: 1.0000 (n=61689)
#
# ============================================================
# Model: Transformer | Dataset: hard | Seed: 42
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.6248 | Val Acc: 0.6445
# Epoch 2/30 | Train Acc: 0.6379 | Val Acc: 0.6330
# Epoch 3/30 | Train Acc: 0.6391 | Val Acc: 0.6457
# Epoch 4/30 | Train Acc: 0.6393 | Val Acc: 0.6380
# Epoch 5/30 | Train Acc: 0.6409 | Val Acc: 0.6467
# Epoch 6/30 | Train Acc: 0.6408 | Val Acc: 0.6462
# Epoch 7/30 | Train Acc: 0.6412 | Val Acc: 0.6468
# Epoch 8/30 | Train Acc: 0.6421 | Val Acc: 0.6481
# Epoch 9/30 | Train Acc: 0.6425 | Val Acc: 0.6511
# Epoch 10/30 | Train Acc: 0.6446 | Val Acc: 0.6525
# Epoch 11/30 | Train Acc: 0.6527 | Val Acc: 0.6939
# Epoch 12/30 | Train Acc: 0.7921 | Val Acc: 0.9179
# Epoch 13/30 | Train Acc: 0.8870 | Val Acc: 0.9499
# Epoch 14/30 | Train Acc: 0.9054 | Val Acc: 0.9633
# Epoch 15/30 | Train Acc: 0.9184 | Val Acc: 0.9575
# Epoch 16/30 | Train Acc: 0.9319 | Val Acc: 0.9884
# Epoch 17/30 | Train Acc: 0.9709 | Val Acc: 0.9984
# Epoch 18/30 | Train Acc: 0.9787 | Val Acc: 0.9948
# Epoch 19/30 | Train Acc: 0.9791 | Val Acc: 1.0000
# Epoch 20/30 | Train Acc: 0.9808 | Val Acc: 0.9929
# Epoch 21/30 | Train Acc: 0.9818 | Val Acc: 0.9913
# Epoch 22/30 | Train Acc: 0.9825 | Val Acc: 0.9878
# Epoch 23/30 | Train Acc: 0.9847 | Val Acc: 0.9997
# Epoch 24/30 | Train Acc: 0.9841 | Val Acc: 1.0000
# Early stopping at epoch 24
#
# Results:
#   Test Accuracy: 0.9999
#   Training Time: 250.7s
#   Length Gen Accuracy: 1.0000 (n=61689)
#
# ============================================================
# Model: Transformer | Dataset: hard | Seed: 123
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.6257 | Val Acc: 0.6357
# Epoch 2/30 | Train Acc: 0.6369 | Val Acc: 0.6361
# Epoch 3/30 | Train Acc: 0.6415 | Val Acc: 0.6381
# Epoch 4/30 | Train Acc: 0.6414 | Val Acc: 0.6387
# Epoch 5/30 | Train Acc: 0.6422 | Val Acc: 0.6394
# Epoch 6/30 | Train Acc: 0.6435 | Val Acc: 0.6407
# Epoch 7/30 | Train Acc: 0.6443 | Val Acc: 0.6415
# Epoch 8/30 | Train Acc: 0.6465 | Val Acc: 0.6353
# Epoch 9/30 | Train Acc: 0.6499 | Val Acc: 0.6417
# Epoch 10/30 | Train Acc: 0.6561 | Val Acc: 0.6595
# Epoch 11/30 | Train Acc: 0.6640 | Val Acc: 0.6592
# Epoch 12/30 | Train Acc: 0.6736 | Val Acc: 0.6909
# Epoch 13/30 | Train Acc: 0.7665 | Val Acc: 0.8976
# Epoch 14/30 | Train Acc: 0.9020 | Val Acc: 0.9759
# Epoch 15/30 | Train Acc: 0.9281 | Val Acc: 0.9875
# Epoch 16/30 | Train Acc: 0.9381 | Val Acc: 0.9838
# Epoch 17/30 | Train Acc: 0.9411 | Val Acc: 0.9651
# Epoch 18/30 | Train Acc: 0.9472 | Val Acc: 0.9919
# Epoch 19/30 | Train Acc: 0.9521 | Val Acc: 0.9757
# Epoch 20/30 | Train Acc: 0.9546 | Val Acc: 0.9875
# Epoch 21/30 | Train Acc: 0.9594 | Val Acc: 0.9825
# Epoch 22/30 | Train Acc: 0.9610 | Val Acc: 0.9853
# Epoch 23/30 | Train Acc: 0.9638 | Val Acc: 0.9980
# Epoch 24/30 | Train Acc: 0.9671 | Val Acc: 0.9848
# Epoch 25/30 | Train Acc: 0.9698 | Val Acc: 0.9759
# Epoch 26/30 | Train Acc: 0.9711 | Val Acc: 0.9967
# Epoch 27/30 | Train Acc: 0.9723 | Val Acc: 0.9985
# Epoch 28/30 | Train Acc: 0.9747 | Val Acc: 0.9933
# Epoch 29/30 | Train Acc: 0.9754 | Val Acc: 0.9983
# Epoch 30/30 | Train Acc: 0.9788 | Val Acc: 0.9982
#
# Results:
#   Test Accuracy: 0.9979
#   Training Time: 313.2s
#   Length Gen Accuracy: 0.9972 (n=61689)
#
# ============================================================
# Model: Transformer | Dataset: hard | Seed: 456
# ============================================================
# Train: 70000 | Val: 15000 | Test: 15000
# Parameters: 117,313
# Epoch 1/30 | Train Acc: 0.6283 | Val Acc: 0.6362
# Epoch 2/30 | Train Acc: 0.6374 | Val Acc: 0.6423
# Epoch 3/30 | Train Acc: 0.6395 | Val Acc: 0.6387
# Epoch 4/30 | Train Acc: 0.6404 | Val Acc: 0.6415
# Epoch 5/30 | Train Acc: 0.6417 | Val Acc: 0.6428
# Epoch 6/30 | Train Acc: 0.6413 | Val Acc: 0.6405
# Epoch 7/30 | Train Acc: 0.6423 | Val Acc: 0.6377
# Epoch 8/30 | Train Acc: 0.6408 | Val Acc: 0.6409
# Epoch 9/30 | Train Acc: 0.6434 | Val Acc: 0.6394
# Epoch 10/30 | Train Acc: 0.6455 | Val Acc: 0.6379
# Early stopping at epoch 10
#
# Results:
#   Test Accuracy: 0.6417
#   Training Time: 104.4s
#   Length Gen Accuracy: 0.6445 (n=61689)
#
# ============================================================
# ALL EXPERIMENTS COMPLETE
# ============================================================

# %%
# %% CELL 14: Save Final Results
results_df = pd.DataFrame(all_results)
results_df.to_csv(f'{OUTPUT_DIR}/f2_results.csv', index=False)
print(f"Results saved to {OUTPUT_DIR}/f2_results.csv")

# Display summary
print("\n" + "="*60)
print("SUMMARY TABLE")
print("="*60)
print(results_df.to_string(index=False))

# %% CELL 15: Summary Statistics
summary = results_df.groupby(['model', 'dataset']).agg({
    'test_acc': ['mean', 'std'],
    'train_time': 'mean'
}).round(4)

print("\n" + "="*60)
print("AGGREGATED RESULTS (mean ± std)")
print("="*60)
print(summary)

# Save summary
summary.to_csv(f'{OUTPUT_DIR}/f2_summary.csv')

# %% CELL 16: Visualization
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plot 1: Test accuracy by model and dataset
pivot = results_df.pivot_table(values='test_acc', index='dataset', columns='model', aggfunc='mean')
pivot.plot(kind='bar', ax=axes[0], rot=0)
axes[0].set_title('F₂ Word Problem: Test Accuracy')
axes[0].set_ylabel('Accuracy')
axes[0].set_ylim(0.5, 1.0)
axes[0].legend(title='Model')

# Plot 2: Training time
pivot_time = results_df.pivot_table(values='train_time', index='dataset', columns='model', aggfunc='mean')
pivot_time.plot(kind='bar', ax=axes[1], rot=0)
axes[1].set_title('F₂ Word Problem: Training Time')
axes[1].set_ylabel('Seconds')
axes[1].legend(title='Model')

plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/f2_results.png', dpi=150)
plt.show()

print(f"\nVisualization saved to {OUTPUT_DIR}/f2_results.png")

# %% CELL 17: Download Results
from google.colab import files
files.download(f'{OUTPUT_DIR}/f2_results.csv')
print("Download complete!")
# Out:
# Results saved to /content/drive/MyDrive/word_problem_results/Z2/f2_results.csv
#
# ============================================================
# SUMMARY TABLE
# ============================================================
#       model   dataset  seed  test_acc  val_acc  train_time  len_gen_acc  len_gen_count  epochs
#        LSTM synthetic    42  1.000000 1.000000  157.291523          NaN              0       9
#        LSTM synthetic   123  1.000000 1.000000  156.687858          NaN              0       9
#        LSTM synthetic   456  1.000000 1.000000  156.614157          NaN              0       9
# Transformer synthetic    42  0.999733 0.999333  210.196327          NaN              0      22
# Transformer synthetic   123  0.995800 0.998333   96.017031          NaN              0      10
# Transformer synthetic   456  0.996267 0.998267   66.963726          NaN              0       7
#        LSTM      anbn    42  1.000000 1.000000  136.778096          NaN              0       8
#        LSTM      anbn   123  1.000000 1.000000  119.082623          NaN              0       7
#        LSTM      anbn   456  1.000000 1.000000  119.610324          NaN              0       7
# Transformer      anbn    42  0.991733 0.998600   86.592571          NaN              0       9
# Transformer      anbn   123  0.995800 0.998867  105.862013          NaN              0      11
# Transformer      anbn   456  0.994733 0.996067   76.767401          NaN              0       8
#        LSTM      hard    42  1.000000 1.000000  292.200887     1.000000          61689      11
#        LSTM      hard   123  1.000000 1.000000  427.069686     1.000000          61689      16
#        LSTM      hard   456  1.000000 1.000000  398.425875     1.000000          61689      15
# Transformer      hard    42  0.999933 1.000000  250.722125     0.999968          61689      24
# Transformer      hard   123  0.997867 0.998467  313.185628     0.997196          61689      30
# Transformer      hard   456  0.641733 0.642800  104.352299     0.644475          61689      10
#
# ============================================================
# AGGREGATED RESULTS (mean ± std)
# ============================================================
#                       test_acc         train_time
#                           mean     std       mean
# model       dataset
# LSTM        anbn        1.0000  0.0000   125.1570
#             hard        1.0000  0.0000   372.5655
#             synthetic   1.0000  0.0000   156.8645
# Transformer anbn        0.9941  0.0021    89.7407
#             hard        0.8798  0.2062   222.7534
#             synthetic   0.9973  0.0021   124.3924
# Visualization saved to /content/drive/MyDrive/word_problem_results/Z2/f2_results.png
# Download complete!
